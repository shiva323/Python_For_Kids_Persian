# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-radius:20px;padding:22px 24px;margin:6px 0 18px;background:linear-gradient(135deg,#F1973D16,transparent);">
#     <div style="font-size:14px;color:#F1973D;font-weight:800;">SESSION 08</div>
#     <div style="font-size:31px;font-weight:900;margin-top:2px;">تصمیم‌گیری با مقایسه و منطق</div>
#     <div style="font-size:17px;color:#697487;margin:8px 0 14px;">Comparison Operators + and / or / not + شرط‌های واقعی</div>
#     <div style="font-weight:800;margin-bottom:4px;">در پایان این جلسه می‌توانی:</div>
#     <ul style="margin:0;padding-right:22px;"><li>مقادیر را با ==، !=، >، <، >= و <= مقایسه کنی</li><li>چند شرط را با and، or و not ترکیب کنی</li><li>از نتیجه True/False داخل if استفاده کنی</li><li>شرط‌های خوانا و واقعی برای برنامه‌ها بنویسی</li></ul>
#   </div>
#   <hr style="border:0;border-top:2px solid #F1973D55;margin:22px 0;">
# </div>

# %% [markdown]
# ![Logic Ninja — comparisons become decisions](attachment:s08_logic_ninja_cartoon.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# Logic Ninja — comparisons become decisions
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #F1973D;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مقایسه یعنی سؤال True/False</strong><span style="background:#F1973D18;color:#F1973D;padding:4px 10px;border-radius:999px;font-weight:700;">Comparison</span>
#     </div>
#     <div style="font-size:16.5px;">عملگرهای مقایسه مقدارها را با هم بررسی می‌کنند و نتیجه همیشه از نوع <code dir='ltr'>bool</code> است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# ![Comparison and logical operators in one visual map](attachment:s08_logic_map.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# Comparison and logical operators in one visual map
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %%
print(7 > 3)
print(5 == 5)
print(4 != 4)
print(8 <= 10)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">عملگرهای مقایسه</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">مرجع</span>
#     </div>
#     <div style="font-size:16.5px;"><code dir='ltr'>==</code> برابر؟ &nbsp; <code dir='ltr'>!=</code> نابرابر؟ &nbsp; <code dir='ltr'>&gt;</code> بزرگ‌تر؟ &nbsp; <code dir='ltr'>&lt;</code> کوچک‌تر؟ &nbsp; <code dir='ltr'>&gt;=</code> بزرگ‌تر یا مساوی؟ &nbsp; <code dir='ltr'>&lt;=</code> کوچک‌تر یا مساوی؟</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #D95252;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">دام مهم: = با == فرق دارد</strong><span style="background:#D9525218;color:#D95252;padding:4px 10px;border-radius:999px;font-weight:700;">باگ</span>
#     </div>
#     <div style="font-size:16.5px;"><code dir='ltr'>=</code> برای مقداردهی است. <code dir='ltr'>==</code> برای مقایسه. این یکی از رایج‌ترین اشتباه‌های شروع برنامه‌نویسی است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">and: همه شرط‌ها باید درست باشند</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">AND</span>
#     </div>
#     <div style="font-size:16.5px;">مثلاً برای ورود به بازی هم سن کافی باشد و هم بلیت داشته باشیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
age = 14
has_ticket = True
print(age >= 12 and has_ticket)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">or: حداقل یکی کافی است</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">OR</span>
#     </div>
#     <div style="font-size:16.5px;">مثلاً برای ورود ویژه، یا VIP باشیم یا دعوت‌نامه داشته باشیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
is_vip = False
has_invitation = True
print(is_vip or has_invitation)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">not: نتیجه را برعکس کن</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">NOT</span>
#     </div>
#     <div style="font-size:16.5px;"><code dir='ltr'>not True</code> می‌شود False و <code dir='ltr'>not False</code> می‌شود True.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
game_over = False
print(not game_over)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #F1973D;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">اولین شرط واقعی با if</strong><span style="background:#F1973D18;color:#F1973D;padding:4px 10px;border-radius:999px;font-weight:700;">IF</span>
#     </div>
#     <div style="font-size:16.5px;">اگر شرط True باشد، کد تورفته زیر <code dir='ltr'>if</code> اجرا می‌شود. تورفتگی در Python بخشی از زبان است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
age = 14
has_ticket = True

if age >= 12 and has_ticket:
    print("✅ اجازه ورود داری")
else:
    print("⛔ اجازه ورود نداری")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مثال عالی ۱: نمره و سطح</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">if / elif / else</span>
#     </div>
#     <div style="font-size:16.5px;">با <code dir='ltr'>elif</code> چند حالت را از بالا به پایین بررسی می‌کنیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
score = 87

if score >= 90:
    print("Level: Excellent")
elif score >= 70:
    print("Level: Good")
elif score >= 50:
    print("Level: Pass")
else:
    print("Level: Try again")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مثال عالی ۲: نام کاربری تمیز</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">ترکیب جلسات</span>
#     </div>
#     <div style="font-size:16.5px;">از جلسه قبل استفاده می‌کنیم: نام را strip و lower می‌کنیم و بعد مقایسه می‌کنیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
username = input("Username: ").strip().lower()

if username == "admin":
    print("Welcome, admin!")
else:
    print(f"Welcome, {username}!")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مثال عالی ۳: رمز ساده</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">String + Logic</span>
#     </div>
#     <div style="font-size:16.5px;">شرط می‌گذاریم طول رمز حداقل 8 باشد و داخلش فاصله نباشد. این فقط تمرین آموزشی است، نه سیستم امنیتی واقعی.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
password = input("Password: ")

if len(password) >= 8 and " " not in password:
    print("✅ Basic format accepted")
else:
    print("❌ Use 8+ characters and no spaces")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مثال عالی ۴: شرط بازه‌ای</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">Range</span>
#     </div>
#     <div style="font-size:16.5px;">در Python می‌توانی مقایسه زنجیره‌ای بنویسی: <code dir='ltr'>10 &lt;= value &lt;= 20</code>.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
temperature = 16

if 10 <= temperature <= 20:
    print("Weather is mild")
else:
    print("Outside the mild range")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #F1973D;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">پروژه: Adventure Gate</strong><span style="background:#F1973D18;color:#F1973D;padding:4px 10px;border-radius:999px;font-weight:700;">پروژه</span>
#     </div>
#     <div style="font-size:16.5px;">سن، داشتن بلیت و اجازه والدین را بگیر. ورود مجاز است اگر سن حداقل 12 باشد و بلیت داشته باشد؛ یا اگر اجازه والدین دارد. سپس پیام مناسب چاپ کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
age = int(input("Age: "))
has_ticket = input("Ticket? yes/no: ").strip().lower() == "yes"
parent_permission = input("Parent permission? yes/no: ").strip().lower() == "yes"

can_enter = (age >= 12 and has_ticket) or parent_permission

if can_enter:
    print("🎮 Welcome to the adventure!")
else:
    print("🚪 Entry denied")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #D95252;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">کارآگاه باگ</strong><span style="background:#D9525218;color:#D95252;padding:4px 10px;border-radius:999px;font-weight:700;">Debug</span>
#     </div>
#     <div style="font-size:16.5px;">سه اشتباه رایج را پیدا کن: استفاده از <code dir='ltr'>=</code> به‌جای <code dir='ltr'>==</code>، نوشتن <code dir='ltr'>AND</code> به‌جای <code dir='ltr'>and</code> و فراموش کردن تورفتگی بعد از if.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #F1973D;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">جمع‌بندی</strong><span style="background:#F1973D18;color:#F1973D;padding:4px 10px;border-radius:999px;font-weight:700;">پایان جلسه</span>
#     </div>
#     <div style="font-size:16.5px;">جلسه ۸ نقطه مهمی است: از اینجا برنامه‌ها دیگر فقط محاسبه نمی‌کنند؛ <b>تصمیم می‌گیرند</b>. مقایسه‌ها True/False می‌سازند و and/or/not این تصمیم‌ها را ترکیب می‌کنند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>
