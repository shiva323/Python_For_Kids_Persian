# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-radius:20px;padding:22px 24px;margin:6px 0 18px;background:linear-gradient(135deg,#4A77FF16,transparent);">
#     <div style="font-size:14px;color:#4A77FF;font-weight:800;">SESSION 01</div>
#     <div style="font-size:31px;font-weight:900;margin-top:2px;">قدم اول: مثل یک برنامه‌نویس فکر کن</div>
#     <div style="font-size:17px;color:#697487;margin:8px 0 14px;">الگوریتم، شبه‌کد و فلوچارت — بدون نیاز به پیش‌زمینه</div>
#     <div style="font-weight:800;margin-bottom:4px;">در پایان این جلسه می‌توانی:</div>
#     <ul style="margin:0;padding-right:22px;"><li>یک کار روزمره را به قدم‌های دقیق تبدیل کنی</li><li>فرق الگوریتم، شبه‌کد و فلوچارت را بفهمی</li><li>دستورهای مبهم را پیدا و اصلاح کنی</li></ul>
#   </div>
#   <hr style="border:0;border-top:2px solid #4A77FF55;margin:22px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">ماموریت امروز</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">۵ دقیقه</span>
#     </div>
#     <div style="font-size:16.5px;">قرار نیست امروز کلی کد حفظ کنیم. هدف این است که یاد بگیریم <b>کامپیوتر حدس نمی‌زند</b>. هر چیزی که می‌خواهیم انجام دهد، باید مرحله‌به‌مرحله و روشن گفته شود.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# ![یک الگوریتم خوب، کار بزرگ را به چند قدم ساده تبدیل می‌کند.](attachment:s01_algorithm_steps.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# یک الگوریتم خوب، کار بزرگ را به چند قدم ساده تبدیل می‌کند.
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">الگوریتم چیست؟</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">یاد بگیر</span>
#     </div>
#     <div style="font-size:16.5px;">الگوریتم یعنی <b>دستورهای مرتب و دقیق برای انجام یک کار یا حل یک مسئله</b>. دستور پخت غذا، مسیر رفتن به مدرسه و قوانین یک بازی هم می‌توانند الگوریتم داشته باشند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">قبل از ادامه حدس بزن</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">پیش‌بینی</span>
#     </div>
#     <div style="font-size:16.5px;">کدام دستور برای ربات بهتر است؟<br><b>A)</b> اتاقت را مرتب کن.<br><b>B)</b> کتاب‌ها را در قفسه بگذار، لباس‌ها را داخل کمد قرار بده و زباله‌ها را داخل سطل بینداز.<br><br>پاسخ را اول برای خودت انتخاب کن، بعد توضیح پایین را بخوان.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">چرا B بهتر است؟</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">توضیح</span>
#     </div>
#     <div style="font-size:16.5px;">چون ربات در دستور B مجبور نیست معنی «مرتب کن» را حدس بزند. در برنامه‌نویسی، <b>دقیق بودن از کوتاه بودن مهم‌تر است</b>.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">شبه‌کد</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">نقشه قبل از کد</span>
#     </div>
#     <div style="font-size:16.5px;">قبل از نوشتن Python می‌توانیم نقشه راه را با زبان ساده بنویسیم. این نوشته کد واقعی نیست، اما منطق برنامه را مشخص می‌کند.<br><br><code dir='ltr'>START → bread → cheese → bread → END</code></div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# ![فلوچارت همان الگوریتم است که با شکل‌ها و پیکان‌ها دیده می‌شود.](attachment:s01_flowchart_symbols.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# فلوچارت همان الگوریتم است که با شکل‌ها و پیکان‌ها دیده می‌شود.
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">فعالیت ۱: الگوریتم مسواک زدن</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">انجام بده</span>
#     </div>
#     <div style="font-size:16.5px;">۶ تا ۹ مرحله بنویس. هر مرحله فقط یک کار مشخص داشته باشد. بعد از خودت بپرس: «آیا یک ربات می‌تواند بدون سؤال اضافه آن را اجرا کند؟»</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">فعالیت ۲: شرط اضافه کن</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">چالش</span>
#     </div>
#     <div style="font-size:16.5px;">حالا یک حالت غیرعادی اضافه کن؛ مثلاً: <b>اگر خمیردندان تمام شده بود چه؟</b> این اولین قدم ما به سمت تصمیم‌گیری در برنامه‌هاست.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">اولین برخورد با Python</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">اجرا کن</span>
#     </div>
#     <div style="font-size:16.5px;">فقط برای اینکه اجرای یک سلول را تجربه کنیم، کد زیر را اجرا کن. لازم نیست هنوز جزئیاتش را حفظ باشی.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
print("سلام برنامه‌نویس آینده! 🚀")
print("من آماده‌ام مرحله‌به‌مرحله فکر کنم.")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">تغییر بده و دوباره اجرا کن</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">آزمایش</span>
#     </div>
#     <div style="font-size:16.5px;">جمله دوم را به یک پیام شخصی تبدیل کن. مثلاً اسم خودت یا هدفی که از یادگیری Python داری بنویس.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">جمع‌بندی</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">پایان جلسه</span>
#     </div>
#     <div style="font-size:16.5px;">الگوریتم = قدم‌های دقیق؛ شبه‌کد = نقشه متنی؛ فلوچارت = نقشه تصویری. اگر بتوانی مسئله را خوب خرد کنی، کدنویسی بعداً خیلی آسان‌تر می‌شود.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>
