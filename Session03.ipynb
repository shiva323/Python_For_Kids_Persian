# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-radius:20px;padding:22px 24px;margin:6px 0 18px;background:linear-gradient(135deg,#815BDA16,transparent);">
#     <div style="font-size:14px;color:#815BDA;font-weight:800;">SESSION 03</div>
#     <div style="font-size:31px;font-weight:900;margin-top:2px;">داده‌ها کجا زندگی می‌کنند؟</div>
#     <div style="font-size:17px;color:#697487;margin:8px 0 14px;">کامنت، f-string، انواع داده، حافظه، تبدیل نوع و خطا</div>
#     <div style="font-weight:800;margin-bottom:4px;">در پایان این جلسه می‌توانی:</div>
#     <ul style="margin:0;padding-right:22px;"><li>با کامنت کد را برای انسان‌ها خواناتر کنی</li><li>با f-string خروجی حرفه‌ای بسازی</li><li>int، float، str و bool را از هم تشخیص بدهی</li><li>RAM و ذخیره دائمی را در حد مقدماتی بفهمی</li><li>نوع داده را تبدیل و خطاهای رایج را تشخیص بدهی</li></ul>
#   </div>
#   <hr style="border:0;border-top:2px solid #815BDA55;margin:22px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">کامنت: یادداشت برای انسان</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">خوانایی</span>
#     </div>
#     <div style="font-size:16.5px;">هر چیزی بعد از <code dir='ltr'>#</code> در همان خط، کامنت است و Python آن را اجرا نمی‌کند. کامنت خوب دلیل یا هدف کد را توضیح می‌دهد؛ نه چیزی که از خود کد معلوم است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
# نام کاربر را برای ساخت کارت خوش‌آمدگویی نگه می‌داریم
name = "سارا"
print(name)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">خروجی خوانا با f-string</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">ابزار</span>
#     </div>
#     <div style="font-size:16.5px;">وقتی متن و متغیر را ترکیب می‌کنیم، f-string یکی از خواناترین روش‌هاست. کافی است قبل از رشته حرف <code dir='ltr'>f</code> بگذاریم و متغیر را داخل آکولاد قرار دهیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
name = "آراد"
age = 12
score = 95
print(f"سلام {name}! تو {age} سال داری و امتیازت {score} است.")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">پیش‌بینی</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">حدس بزن</span>
#     </div>
#     <div style="font-size:16.5px;">اگر مقدار <code dir='ltr'>score</code> را از 95 به 100 تغییر دهی، کدام قسمت خروجی عوض می‌شود؟ بدون اجرا جواب بده، بعد امتحان کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# ![چهار نوع داده پایه‌ای که در بیشتر برنامه‌های ابتدایی با آن‌ها کار می‌کنیم.](attachment:s03_data_types.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# چهار نوع داده پایه‌ای که در بیشتر برنامه‌های ابتدایی با آن‌ها کار می‌کنیم.
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">نوع داده یعنی چه؟</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">مفهوم</span>
#     </div>
#     <div style="font-size:16.5px;">نوع داده به Python می‌گوید یک مقدار چیست و چه کارهایی روی آن معنی دارد. <code dir='ltr'>25</code> یک int است اما <code dir='ltr'>&quot;25&quot;</code> یک str است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
print(type(25))
print(type(3.14))
print(type("سلام"))
print(type(True))

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #D95252;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">یک تفاوت مهم</strong><span style="background:#D9525218;color:#D95252;padding:4px 10px;border-radius:999px;font-weight:700;">نکته کلیدی</span>
#     </div>
#     <div style="font-size:16.5px;"><code dir='ltr'>10 + 5</code> نتیجه 15 می‌دهد؛ اما <code dir='ltr'>&quot;10&quot; + &quot;5&quot;</code> نتیجه «105» می‌دهد. چون در حالت دوم Python دو متن را به هم می‌چسباند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
print(10 + 5)
print("10" + "5")

# %% [markdown]
# ![مدل ساده: داده‌های برنامه هنگام اجرا در RAM هستند؛ برای ماندگاری باید در فایل ذخیره شوند.](attachment:s03_memory.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# مدل ساده: داده‌های برنامه هنگام اجرا در RAM هستند؛ برای ماندگاری باید در فایل ذخیره شوند.
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #4A77FF;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">داده‌ها واقعاً کجا می‌روند؟</strong><span style="background:#4A77FF18;color:#4A77FF;padding:4px 10px;border-radius:999px;font-weight:700;">درک سیستم</span>
#     </div>
#     <div style="font-size:16.5px;">در زمان اجرای برنامه، مقدارها معمولاً در RAM نگهداری می‌شوند. RAM سریع و موقتی است. فایل روی SSD/HDD برای نگهداری اطلاعات بعد از بستن برنامه استفاده می‌شود. فعلاً همین مدل ذهنی کافی است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">input یک غافلگیری دارد</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">خیلی مهم</span>
#     </div>
#     <div style="font-size:16.5px;">خروجی <code dir='ltr'>input()</code> همیشه متن است. اگر کاربر 12 وارد کند، Python آن را مثل <code dir='ltr'>&quot;12&quot;</code> می‌بیند تا زمانی که خودمان تبدیلش کنیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
age = input("چند سال داری؟ ")
print(type(age))

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">تبدیل نوع</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">ابزار</span>
#     </div>
#     <div style="font-size:16.5px;">از <code dir='ltr'>int()</code>، <code dir='ltr'>float()</code> و <code dir='ltr'>str()</code> استفاده می‌کنیم تا نوع داده را آگاهانه عوض کنیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
age = int(input("چند سال داری؟ "))
print(f"سال آینده {age + 1} ساله می‌شوی.")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #D95252;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">کارآگاه خطا</strong><span style="background:#D9525218;color:#D95252;padding:4px 10px;border-radius:999px;font-weight:700;">باگ</span>
#     </div>
#     <div style="font-size:16.5px;">این کد چرا مشکل دارد؟<br><code dir='ltr'>age = &quot;12&quot;</code><br><code dir='ltr'>print(age + 1)</code><br><br>نوع داده دو طرف عملگر + یکی نیست؛ اینجا به TypeError می‌رسیم.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">خطاها = سرنخ</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">دیباگ</span>
#     </div>
#     <div style="font-size:16.5px;"><b>ValueError</b>: مقدار قابل تبدیل نیست. &nbsp; <b>TypeError</b>: نوع مناسب عملیات نیست. &nbsp; <b>NameError</b>: اسم متغیر پیدا نشد. &nbsp; <b>SyntaxError</b>: ساختار کد اشتباه است.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مینی‌پروژه: کارت بازیکن</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">بساز</span>
#     </div>
#     <div style="font-size:16.5px;">نام، سن، تعداد سکه و قد را بگیر. سن و سکه باید int باشند و قد float. خروجی را فقط با f-string مرتب چاپ کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
name = input("نام بازیکن: ")
age = int(input("سن: "))
coins = int(input("تعداد سکه: "))
height = float(input("قد به متر: "))

print(f"🎮 {name} | سن: {age} | سکه: {coins} | قد: {height} متر")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">چالش ارتقا</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">+۱ مرحله</span>
#     </div>
#     <div style="font-size:16.5px;">یک متغیر <code dir='ltr'>future_coins</code> بساز که 10 سکه بیشتر از مقدار فعلی باشد و آن را در خروجی نشان بده.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">جمع‌بندی</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">پایان جلسه</span>
#     </div>
#     <div style="font-size:16.5px;">نوع داده فقط اسم نیست؛ روی رفتار کد اثر می‌گذارد. از این جلسه به بعد همیشه بپرس: «این مقدار چه نوعی است؟»</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>
