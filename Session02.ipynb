# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-radius:20px;padding:22px 24px;margin:6px 0 18px;background:linear-gradient(135deg,#16A49A16,transparent);">
#     <div style="font-size:14px;color:#16A49A;font-weight:800;">SESSION 02</div>
#     <div style="font-size:31px;font-weight:900;margin-top:2px;">به کامپیوتر حرف زدن را یاد بده</div>
#     <div style="font-size:17px;color:#697487;margin:8px 0 14px;">print، input، متغیرها و نام‌گذاری</div>
#     <div style="font-weight:800;margin-bottom:4px;">در پایان این جلسه می‌توانی:</div>
#     <ul style="margin:0;padding-right:22px;"><li>با print خروجی تولید کنی</li><li>با input از کاربر اطلاعات بگیری</li><li>اطلاعات را داخل متغیر ذخیره کنی</li><li>اسم‌های خوانا برای متغیرها انتخاب کنی</li></ul>
#   </div>
#   <hr style="border:0;border-top:2px solid #16A49A55;margin:22px 0;">
# </div>

# %% [markdown]
# ![الگوی ساده‌ای که بارها در برنامه‌ها می‌بینی: ورودی → پردازش → خروجی](attachment:s02_ipo.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# الگوی ساده‌ای که بارها در برنامه‌ها می‌بینی: ورودی → پردازش → خروجی
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #16A49A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">print یعنی صدای برنامه</strong><span style="background:#16A49A18;color:#16A49A;padding:4px 10px;border-radius:999px;font-weight:700;">یاد بگیر</span>
#     </div>
#     <div style="font-size:16.5px;">وقتی می‌خواهیم Python چیزی روی صفحه نشان دهد از <code dir='ltr'>print()</code> استفاده می‌کنیم. متن‌ها داخل کوتیشن قرار می‌گیرند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
print("سلام دنیا!")
print("من دارم Python یاد می‌گیرم 😎")

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">آزمایش کوچک</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">تغییر بده</span>
#     </div>
#     <div style="font-size:16.5px;">جمله دوم را عوض کن. بعد یک print سوم اضافه کن که غذای مورد علاقه‌ات را نشان دهد.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #16A49A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">input یعنی گوش برنامه</strong><span style="background:#16A49A18;color:#16A49A;padding:4px 10px;border-radius:999px;font-weight:700;">یاد بگیر</span>
#     </div>
#     <div style="font-size:16.5px;">با <code dir='ltr'>input()</code> برنامه سؤال می‌پرسد و منتظر جواب کاربر می‌ماند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
name = input("اسمت چیه؟ ")
print("سلام", name)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">قبل از اجرا پیش‌بینی کن</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">پیش‌بینی</span>
#     </div>
#     <div style="font-size:16.5px;">اگر کاربر بنویسد «سارا»، مقدار متغیر <code dir='ltr'>name</code> چه خواهد شد؟ و print چه چیزی نشان می‌دهد؟ اول حدس بزن، بعد اجرا کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# ![متغیر را مثل یک برچسب تصور کن که ما را به یک مقدار می‌رساند.](attachment:s02_variable_box.png)
#
# <div dir="rtl" style="text-align:center;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;color:#697487;font-size:14px;margin-top:6px;">
# متغیر را مثل یک برچسب تصور کن که ما را به یک مقدار می‌رساند.
# </div>
#
# <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #16A49A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">متغیر چیست؟</strong><span style="background:#16A49A18;color:#16A49A;padding:4px 10px;border-radius:999px;font-weight:700;">مفهوم</span>
#     </div>
#     <div style="font-size:16.5px;">متغیر یک نام است که به یک مقدار اشاره می‌کند. مثال: <code dir='ltr'>age = 12</code>. اسم خوب باعث می‌شود کد خودت را هفته بعد هم بفهمی.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #E68A3A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">نام خوب یا بد؟</strong><span style="background:#E68A3A18;color:#E68A3A;padding:4px 10px;border-radius:999px;font-weight:700;">قانون</span>
#     </div>
#     <div style="font-size:16.5px;">✅ <code dir='ltr'>player_score</code> &nbsp;&nbsp; ✅ <code dir='ltr'>favorite_food</code><br>❌ <code dir='ltr'>2name</code> &nbsp;&nbsp; ❌ <code dir='ltr'>player score</code> &nbsp;&nbsp; ❌ <code dir='ltr'>my-name</code></div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #D95252;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">کارآگاه باگ</strong><span style="background:#D9525218;color:#D95252;padding:4px 10px;border-radius:999px;font-weight:700;">باگ</span>
#     </div>
#     <div style="font-size:16.5px;">کد زیر مشکل دارد. قبل از اصلاح، مشکل را پیدا کن:<br><code dir='ltr'>player score = 100</code><br><br>راهنمایی: نام متغیر نمی‌تواند فاصله داشته باشد.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #815BDA;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">مینی‌پروژه: کارت معرفی</strong><span style="background:#815BDA18;color:#815BDA;padding:4px 10px;border-radius:999px;font-weight:700;">بساز</span>
#     </div>
#     <div style="font-size:16.5px;">نام، سن، بازی مورد علاقه و شغل رؤیایی را از کاربر بگیر و یک کارت معرفی چاپ کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %%
name = input("نام: ")
age = input("سن: ")
game = input("بازی مورد علاقه: ")
dream_job = input("شغل رؤیایی: ")

print("⭐ کارت معرفی ⭐")
print("نام:", name)
print("سن:", age)
print("بازی:", game)
print("شغل رؤیایی:", dream_job)

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #2FA86E;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">چالش ارتقا</strong><span style="background:#2FA86E18;color:#2FA86E;padding:4px 10px;border-radius:999px;font-weight:700;">+۱ مرحله</span>
#     </div>
#     <div style="font-size:16.5px;">یک سؤال پنجم به انتخاب خودت اضافه کن و خروجی کارت را جذاب‌تر کن.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>

# %% [markdown]
# <div dir="rtl" style="direction:rtl;text-align:right;font-family:'Vazirmatn','Noto Sans Arabic','Tahoma','Segoe UI',Arial,sans-serif;line-height:2;">
#   <div style="border:1px solid #d9e0eb;border-right:5px solid #16A49A;border-radius:14px;padding:16px 18px;margin:10px 0 18px 0;">
#     <div style="display:flex;gap:10px;align-items:center;justify-content:flex-start;flex-wrap:wrap;margin-bottom:8px;">
#       <strong style="font-size:21px;">جمع‌بندی</strong><span style="background:#16A49A18;color:#16A49A;padding:4px 10px;border-radius:999px;font-weight:700;">پایان جلسه</span>
#     </div>
#     <div style="font-size:16.5px;">امروز برنامه هم حرف زد و هم گوش داد. جلسه بعد می‌فهمیم چرا «12» همیشه واقعاً عدد نیست و داده‌ها چه نوع‌هایی دارند.</div>
#   </div>
#   <hr style="border:0;border-top:1px solid rgba(120,130,150,.28);margin:20px 0;">
# </div>
